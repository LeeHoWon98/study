# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %%
import tensorflow_datasets as tfds

tfds.list_builders()
# Out:
# ['abstract_reasoning',
#  'accentdb',
#  'aeslc',
#  'aflw2k3d',
#  'ag_news_subset',
#  'ai2_arc',
#  'ai2_arc_with_ir',
#  'amazon_us_reviews',
#  'anli',
#  'arc',
#  'bair_robot_pushing_small',
#  'bccd',
#  'beans',
#  'big_patent',
#  'bigearthnet',
#  'billsum',
#  'binarized_mnist',
#  'binary_alpha_digits',
#  'blimp',
#  'bool_q',
#  'c4',
#  'caltech101',
#  'caltech_birds2010',
#  'caltech_birds2011',
#  'cars196',
#  'cassava',
#  'cats_vs_dogs',
#  'celeb_a',
#  'celeb_a_hq',
#  'cfq',
#  'chexpert',
#  'cifar10',
#  'cifar100',
#  'cifar10_1',
#  'cifar10_corrupted',
#  'citrus_leaves',
#  'cityscapes',
#  'civil_comments',
#  'clevr',
#  'clic',
#  'clinc_oos',
#  'cmaterdb',
#  'cnn_dailymail',
#  'coco',
#  'coco_captions',
#  'coil100',
#  'colorectal_histology',
#  'colorectal_histology_large',
#  'common_voice',
#  'coqa',
#  'cos_e',
#  'cosmos_qa',
#  'covid19sum',
#  'crema_d',
#  'curated_breast_imaging_ddsm',
#  'cycle_gan',
#  'deep_weeds',
#  'definite_pronoun_resolution',
#  'dementiabank',
#  'diabetic_retinopathy_detection',
#  'div2k',
#  'dmlab',
#  'downsampled_imagenet',
#  'dsprites',
#  'dtd',
#  'duke_ultrasound',
#  'emnist',
#  'eraser_multi_rc',
#  'esnli',
#  'eurosat',
#  'fashion_mnist',
#  'flic',
#  'flores',
#  'food101',
#  'forest_fires',
#  'fuss',
#  'gap',
#  'geirhos_conflict_stimuli',
#  'genomics_ood',
#  'german_credit_numeric',
#  'gigaword',
#  'glue',
#  'goemotions',
#  'gpt3',
#  'groove',
#  'gtzan',
#  'gtzan_music_speech',
#  'hellaswag',
#  'higgs',
#  'horses_or_humans',
#  'i_naturalist2017',
#  'imagenet2012',
#  'imagenet2012_corrupted',
#  'imagenet2012_real',
#  'imagenet2012_subset',
#  'imagenet_a',
#  'imagenet_r',
#  'imagenet_resized',
#  'imagenet_v2',
#  'imagenette',
#  'imagewang',
#  'imdb_reviews',
#  'irc_disentanglement',
#  'iris',
#  'kitti',
#  'kmnist',
#  'lfw',
#  'librispeech',
#  'librispeech_lm',
#  'libritts',
#  'ljspeech',
#  'lm1b',
#  'lost_and_found',
#  'lsun',
#  'malaria',
#  'math_dataset',
#  'mctaco',
#  'mnist',
#  'mnist_corrupted',
#  'movie_lens',
#  'movie_rationales',
#  'movielens',
#  'moving_mnist',
#  'multi_news',
#  'multi_nli',
#  'multi_nli_mismatch',
#  'natural_questions',
#  'natural_questions_open',
#  'newsroom',
#  'nsynth',
#  'nyu_depth_v2',
#  'omniglot',
#  'open_images_challenge2019_detection',
#  'open_images_v4',
#  'openbookqa',
#  'opinion_abstracts',
#  'opinosis',
#  'opus',
#  'oxford_flowers102',
#  'oxford_iiit_pet',
#  'para_crawl',
#  'patch_camelyon',
#  'paws_wiki',
#  'paws_x_wiki',
#  'pet_finder',
#  'pg19',
#  'places365_small',
#  'plant_leaves',
#  'plant_village',
#  'plantae_k',
#  'qa4mre',
#  'qasc',
#  'quickdraw_bitmap',
#  'radon',
#  'reddit',
#  'reddit_disentanglement',
#  'reddit_tifu',
#  'resisc45',
#  'robonet',
#  'rock_paper_scissors',
#  'rock_you',
#  'salient_span_wikipedia',
#  'samsum',
#  'savee',
#  'scan',
#  'scene_parse150',
#  'scicite',
#  'scientific_papers',
#  'sentiment140',
#  'shapes3d',
#  'smallnorb',
#  'snli',
#  'so2sat',
#  'speech_commands',
#  'spoken_digit',
#  'squad',
#  'stanford_dogs',
#  'stanford_online_products',
#  'starcraft_video',
#  'stl10',
#  'sun397',
#  'super_glue',
#  'svhn_cropped',
#  'ted_hrlr_translate',
#  'ted_multi_translate',
#  'tedlium',
#  'tf_flowers',
#  'the300w_lp',
#  'tiny_shakespeare',
#  'titanic',
#  'trec',
#  'trivia_qa',
#  'tydi_qa',
#  'uc_merced',
#  'ucf101',
#  'vctk',
#  'vgg_face2',
#  'visual_domain_decathlon',
#  'voc',
#  'voxceleb',
#  'voxforge',
#  'waymo_open_dataset',
#  'web_questions',
#  'wider_face',
#  'wiki40b',
#  'wikihow',
#  'wikipedia',
#  'wikipedia_toxicity_subtypes',
#  'wine_quality',
#  'winogrande',
#  'wmt14_translate',
#  'wmt15_translate',
#  'wmt16_translate',
#  'wmt17_translate',
#  'wmt18_translate',
#  'wmt19_translate',
#  'wmt_t2t_translate',
#  'wmt_translate',
#  'wordnet',
#  'xnli',
#  'xquad',
#  'xsum',
#  'yelp_polarity_reviews',
#  'yes_no']

# %%
# %tensorflow_version 2.x

# %%
celeb_a = tfds.load('celeb_a')
# Out:
# Downloading and preparing dataset celeb_a/2.0.1 (download: 1.38 GiB, generated: 1.62 GiB, total: 3.00 GiB) to /root/tensorflow_datasets/celeb_a/2.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ---------------------------------------------------------------------------
# DownloadError                             Traceback (most recent call last)
# <ipython-input-14-36661f6775fe> in <module>()
# ----> 1 celeb_a = tfds.load('celeb_a')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     342   if download:
#     343     download_and_prepare_kwargs = download_and_prepare_kwargs or {}
# --> 344     dbuilder.download_and_prepare(**download_and_prepare_kwargs)
#     345
#     346   if as_dataset_kwargs is None:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py in download_and_prepare(self, download_dir, download_config)
#     385           self._download_and_prepare(
#     386               dl_manager=dl_manager,
# --> 387               download_config=download_config)
#     388
#     389           # NOTE: If modifying the lines below to put additional information in
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, download_config)
#    1022     super(GeneratorBasedBuilder, self)._download_and_prepare(
#    1023         dl_manager=dl_manager,
# -> 1024         max_examples_per_split=download_config.max_examples_per_split,
#    1025     )
#    1026
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py in _download_and_prepare(self, dl_manager, **prepare_split_kwargs)
#     960         prepare_split_kwargs)
#     961     for split_generator in self._split_generators(
# --> 962         dl_manager, **split_generators_kwargs):
#     963       if str(split_generator.split_info.name).lower() == "all":
#     964         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/image/celeba.py in _split_generators(self, dl_manager)
#     130         "list_eval_partition": EVAL_LIST,
#     131         "list_attr_celeba": ATTR_DATA,
# --> 132         "landmarks_celeba": LANDMARKS_DATA,
#     133     })
#     134
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/download_manager.py in download(self, url_or_urls)
#     543     # Add progress bar to follow the download state
#     544     with self._downloader.tqdm():
# --> 545       return _map_promise(self._download, url_or_urls)
#     546
#     547   def iter_archive(self, resource):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/download_manager.py in _map_promise(map_fn, all_inputs)
#     634   """Map the function into each element and resolve the promise."""
#     635   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 636   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     637   return res
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/download_manager.py in <lambda>(p)
#     634   """Map the function into each element and resolve the promise."""
#     635   all_promises = tf.nest.map_structure(map_fn, all_inputs)  # Apply the function
# --> 636   res = tf.nest.map_structure(lambda p: p.get(), all_promises)  # Wait promises
#     637   return res
#
# /usr/local/lib/python3.7/dist-packages/promise/promise.py in get(self, timeout)
#     510         target = self._target()
#     511         self._wait(timeout or DEFAULT_TIMEOUT)
# --> 512         return self._target_settled_value(_raise=True)
#     513
#     514     def _target_settled_value(self, _raise=False):
#
# /usr/local/lib/python3.7/dist-packages/promise/promise.py in _target_settled_value(self, _raise)
#     514     def _target_settled_value(self, _raise=False):
#     515         # type: (bool) -> Any
# --> 516         return self._target()._settled_value(_raise)
#     517
#     518     _value = _reason = _target_settled_value
#
# /usr/local/lib/python3.7/dist-packages/promise/promise.py in _settled_value(self, _raise)
#     224             if _raise:
#     225                 raise_val = self._fulfillment_handler0
# --> 226                 reraise(type(raise_val), raise_val, self._traceback)
#     227             return self._fulfillment_handler0
#     228
#
# /usr/local/lib/python3.7/dist-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# /usr/local/lib/python3.7/dist-packages/promise/promise.py in handle_future_result(future)
#     842         # type: (Any) -> None
#     843         try:
# --> 844             resolve(future.result())
#     845         except Exception as e:
#     846             tb = exc_info()[2]
#
# /usr/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     426                 raise CancelledError()
#     427             elif self._state == FINISHED:
# --> 428                 return self.__get_result()
#     429
#     430             self._condition.wait(timeout)
#
# /usr/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# /usr/lib/python3.7/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/downloader.py in _sync_download(self, url, destination_path)
#     182       pass
#     183
# --> 184     with _open_url(url) as (response, iter_content):
#     185       fname = _get_filename(response)
#     186       path = os.path.join(destination_path, fname)
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/downloader.py in _open_with_requests(url)
#     227   with requests.Session() as session:
#     228     if _DRIVE_URL.match(url):
# --> 229       url = _get_drive_url(url, session)
#     230     with session.get(url, stream=True) as response:
#     231       _assert_status(response)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/downloader.py in _get_drive_url(url, session)
#     245   """Returns url, possibly with confirmation token."""
#     246   with session.get(url, stream=True) as response:
# --> 247     _assert_status(response)
#     248     for k, v in response.cookies.items():
#     249       if k.startswith('download_warning'):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/download/downloader.py in _assert_status(response)
#     257   if response.status_code != 200:
#     258     raise DownloadError('Failed to get url {}. HTTP code: {}.'.format(
# --> 259         response.url, response.status_code))
#
# DownloadError: Failed to get url https://drive.google.com/uc?export=download&id=0B7EVK8r0v71pZjFTYXZWM3FlRnM. HTTP code: 404.

# %% [markdown]
# 데이터 로드가 진행되지 않아 따로 데이터를 다운받고 사용하겠습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -al /content/drive/'MyDrive'/celeba_small.npz
# Out:
# -rw------- 1 root root 173961605 Mar  9 16:32 /content/drive/MyDrive/celeba_small.npz

# %%
celeba_small = np.load('/content/drive/MyDrive/celeba_small.npz')

# %%
list(celeba_small.keys())
# Out:
# ['train_images', 'train_labels', 'test_images', 'test_labels']

# %%
x = celeba_small['train_images'][0]
y = celeba_small['train_labels'][0]

# %%
print(x.shape)
print(y.shape)
# Out:
# (72, 59, 3)
# (2,)

# %%
plt.imshow(celeba_small['train_images'][3])
plt.show()
print(celeba_small['train_labels'][3])
# Out:
# [1 1]

# %%
celeba_small = np.load('/content/drive/MyDrive/celeba_small.npz')
train_images = celeba_small['train_images']
test_images = celeba_small['test_images']

train_labels = celeba_small['train_labels']
test_labels = celeba_small['test_labels']

# %%
train_images[train_images != 0][:10]
# Out:
# array([0.02352941, 0.04313725, 0.05490196, 0.01960784, 0.03921569,
#        0.05490196, 0.01977401, 0.03921569, 0.05114656, 0.02352941])

# %%
train_images.dtype
# Out:
# dtype('float64')

# %%
print(train_images.max(), train_images.min())
print(train_labels.max(), train_labels.min())

print(test_images.max(), test_images.min())
print(test_labels.max(), test_labels.min())
# Out:
# 1.0 0.0
# 1 0
# 1.0 0.0
# 1 0

# %%
from tensorflow.keras.utils import to_categorical
train_male_labels, train_smile_labels = np.split(train_labels, 2, axis = 1)
test_male_labels, test_smile_labels = np.split(test_labels, 2, axis = 1)
print(train_male_labels.shape, train_smile_labels.shape)
print(test_male_labels.shape, test_smile_labels.shape)
# Out:
# (2000, 1) (2000, 1)
# (200, 1) (200, 1)

# %%
train_male_labels = to_categorical(train_male_labels)
train_smile_labels = to_categorical(train_smile_labels)
test_male_labels = to_categorical(test_male_labels)
test_smile_labels = to_categorical(test_smile_labels)

# %%
print(train_male_labels.shape)
print(train_smile_labels.shape)
print(test_male_labels.shape)
print(test_smile_labels.shape)
# Out:
# (2000, 2)
# (2000, 2)
# (200, 2)
# (200, 2)

# %%
train_labels2 = np.concatenate([train_male_labels, train_smile_labels], axis = 1)
test_labels2 = np.concatenate([test_male_labels, test_smile_labels], axis = 1)
print(train_labels2.shape)
print(test_labels2.shape)
# Out:
# (2000, 4)
# (200, 4)

# %%
plt.imshow(np.hstack(train_images[:5]))
print(train_labels[:5])
plt.show()
# Out:
# [[0 0]
#  [1 1]
#  [1 0]
#  [1 1]
#  [1 1]]

# %%
from keras.models import Model
from keras.layers import Conv2D, MaxPool2D, Input, Flatten, Dense

def simple_model():
  inputs = Input((72, 59, 3))

  x = Conv2D(32, 3, activation = 'relu')(inputs)
  x = MaxPool2D(2)(x)
  x = Conv2D(64, 3, activation = 'relu')(x)
  x = MaxPool2D(2)(x)
  x = Conv2D(64, 3, activation = 'relu')(x)
  x = MaxPool2D(2)(x)

  x = Flatten()(x)
  x = Dense(64, activation='relu')(x)

  outputs = Dense(2, activation='softmax')(x)
  model = Model(inputs, outputs)
  return model

# %%
gender_model = simple_model()
smile_model = simple_model()

# %%
gender_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 72, 59, 3)]       0
#
#  conv2d (Conv2D)             (None, 70, 57, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 35, 28, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 33, 26, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 13, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 14, 11, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2240)              0
#
#  dense (Dense)               (None, 64)                143424
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 199,874
# Trainable params: 199,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
smile_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 72, 59, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 70, 57, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 35, 28, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 33, 26, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 13, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 14, 11, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2240)              0
#
#  dense_2 (Dense)             (None, 64)                143424
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 199,874
# Trainable params: 199,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
gender_model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
smile_model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
gender_hist = gender_model.fit(train_images, train_male_labels, validation_data=(test_images, test_male_labels), epochs=15, verbose = 1)
# Out:
# Epoch 1/15
# 63/63 [==============================] - 11s 21ms/step - loss: 0.5941 - accuracy: 0.6695 - val_loss: 0.5363 - val_accuracy: 0.7250
# Epoch 2/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.4570 - accuracy: 0.7890 - val_loss: 0.4430 - val_accuracy: 0.8400
# Epoch 3/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.3079 - accuracy: 0.8655 - val_loss: 0.3229 - val_accuracy: 0.8950
# Epoch 4/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.2002 - accuracy: 0.9180 - val_loss: 0.2653 - val_accuracy: 0.9000
# Epoch 5/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.1490 - accuracy: 0.9440 - val_loss: 0.2379 - val_accuracy: 0.9150
# Epoch 6/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.1146 - accuracy: 0.9605 - val_loss: 0.2982 - val_accuracy: 0.9050
# Epoch 7/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.1054 - accuracy: 0.9540 - val_loss: 0.2280 - val_accuracy: 0.9200
# Epoch 8/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0709 - accuracy: 0.9725 - val_loss: 0.2252 - val_accuracy: 0.9050
# Epoch 9/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0504 - accuracy: 0.9845 - val_loss: 0.2349 - val_accuracy: 0.9250
# Epoch 10/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0315 - accuracy: 0.9885 - val_loss: 0.2477 - val_accuracy: 0.9250
# Epoch 11/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0264 - accuracy: 0.9925 - val_loss: 0.3531 - val_accuracy: 0.8700
# Epoch 12/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0381 - accuracy: 0.9845 - val_loss: 0.3036 - val_accuracy: 0.9300
# Epoch 13/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0378 - accuracy: 0.9875 - val_loss: 0.2612 - val_accuracy: 0.8950
# Epoch 14/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.2838 - val_accuracy: 0.9250
# Epoch 15/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0139 - accuracy: 0.9975 - val_loss: 0.2305 - val_accuracy: 0.9400

# %%
smile_hist = smile_model.fit(train_images, train_smile_labels, validation_data=(test_images, test_smile_labels), epochs=15, verbose = 1)
# Out:
# Epoch 1/15
# 63/63 [==============================] - 2s 19ms/step - loss: 0.6928 - accuracy: 0.5200 - val_loss: 0.7093 - val_accuracy: 0.4850
# Epoch 2/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.6761 - accuracy: 0.5780 - val_loss: 0.6529 - val_accuracy: 0.6300
# Epoch 3/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.6269 - accuracy: 0.6425 - val_loss: 0.5326 - val_accuracy: 0.7500
# Epoch 4/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.4814 - accuracy: 0.7820 - val_loss: 0.3696 - val_accuracy: 0.8300
# Epoch 5/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.3473 - accuracy: 0.8525 - val_loss: 0.2776 - val_accuracy: 0.8900
# Epoch 6/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.2841 - accuracy: 0.8835 - val_loss: 0.2821 - val_accuracy: 0.8800
# Epoch 7/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.2505 - accuracy: 0.8885 - val_loss: 0.2441 - val_accuracy: 0.9200
# Epoch 8/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.2326 - accuracy: 0.9085 - val_loss: 0.2064 - val_accuracy: 0.9050
# Epoch 9/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.1972 - accuracy: 0.9240 - val_loss: 0.2110 - val_accuracy: 0.8950
# Epoch 10/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.1580 - accuracy: 0.9395 - val_loss: 0.2304 - val_accuracy: 0.9050
# Epoch 11/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.1210 - accuracy: 0.9595 - val_loss: 0.2021 - val_accuracy: 0.9050
# Epoch 12/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.1025 - accuracy: 0.9565 - val_loss: 0.2216 - val_accuracy: 0.9300
# Epoch 13/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.1080 - accuracy: 0.9580 - val_loss: 0.2429 - val_accuracy: 0.9100
# Epoch 14/15
# 63/63 [==============================] - 1s 13ms/step - loss: 0.0683 - accuracy: 0.9780 - val_loss: 0.2587 - val_accuracy: 0.9200
# Epoch 15/15
# 63/63 [==============================] - 1s 14ms/step - loss: 0.0507 - accuracy: 0.9830 - val_loss: 0.2745 - val_accuracy: 0.9250

# %%
plt.plot(gender_hist.history['accuracy'], label = 'gender_accuracy')
plt.plot(gender_hist.history['loss'], label = 'gender_loss')
plt.plot(gender_hist.history['val_accuracy'], label = 'gender_val_accuracy')
plt.plot(gender_hist.history['val_loss'], label = 'gender_val_loss')

plt.plot(smile_hist.history['accuracy'], label = 'smile_accuracy')
plt.plot(smile_hist.history['loss'], label = 'smile_loss')
plt.plot(smile_hist.history['val_accuracy'], label = 'smile_val_accuracy')
plt.plot(smile_hist.history['val_loss'], label = 'smile_val_loss')

plt.legend(loc = 'uppder left')
plt.show()

# %%
gender_res = gender_model.predict(test_images[0:1])
gender_res.shape
# Out:
# (1, 2)

# %%
smile_res = smile_model.predict(test_images[0:1])
smile_res.shape
# Out:
# (1, 2)

# %%
plt.imshow(test_images[0])
plt.show()

# %%
print(gender_res)
print(smile_res)

# [여자 : 남자]
# [안웃음 : 웃음]
# Out:
# [[4.4814537e-06 9.9999547e-01]]
# [[2.230807e-05 9.999777e-01]]

# %%
plt.bar(range(2), gender_res[0])
plt.bar(np.array(range(2)) + 0.3, test_male_labels[0])
plt.show()

# %%
plt.bar(range(2), smile_res[0])
plt.bar(np.array(range(2)) + 0.3, test_smile_labels[0])
plt.show()
